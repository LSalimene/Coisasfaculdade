# %% [markdown]
# <a href="https://colab.research.google.com/github/LSalimene/Coisasfaculdade/blob/master/turbulencia_media.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
#dados do dia 2 de maio de 2014
dados = pd.read_csv(('../content/drive/My Drive/L_2014_122_1200.dat'),header=None)
#importar cada variavel
ano = pd.DataFrame(dados,columns=[0])
dia = pd.DataFrame(dados,columns=[1])
hhmm = pd.DataFrame(dados,columns=[2])
seg = pd.DataFrame(dados,columns=[3])
u1 = pd.DataFrame(dados,columns=[4])
v1 = pd.DataFrame(dados,columns=[5])
w1 = pd.DataFrame(dados,columns=[6])
ts = pd.DataFrame(dados,columns=[7])
co2 = pd.DataFrame(dados,columns=[8])
h2o = pd.DataFrame(dados,columns=[9])
p = pd.DataFrame(dados,columns=[11])
#arrumar o tempo dos dados
min = hhmm-1200
mms = min*60
a=np.add(mms,seg)
r=11999+1
i0=0
w10 = w1[int(i0):int(r)]
t10 = a [int(i0):int(r)]
b = w10*0
media = np.mean(w10)
print(media)
meanw = np.add (b,media)
#plotar a imagem
plt.style.use('seaborn')
plt.plot(t10,w10,'g')
plt.hold = True
plt.plot(t10,meanw,'b')
plt.xlabel('Segundos')
plt.ylabel('W1')
plt.title('W1 por tempo')
#desconsiderar tempos maiores que uma hora para o grafico ficar mais bonito
#plt.xlim (0,3600)
#salvar o grafico
plt.savefig('u1v1.png')
#files.download('u1v1.png')
plt.show()
# Out:
# 6    0.030338
# dtype: float64
